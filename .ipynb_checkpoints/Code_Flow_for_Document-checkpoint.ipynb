# %%
import pandas as pd  

cars = pd.read_csv('Online Dataset/Online_Dataset.csv')
cars.isnull().sum()
# Out:
# Id                   0
# Model                0
# Price                0
# Age_08_04            0
# Mfg_Month            0
# Mfg_Year             0
# KM                   0
# Fuel_Type            0
# HP                   0
# Met_Color            0
# Color                0
# Automatic            0
# CC                   0
# Doors                0
# Cylinders            0
# Gears                0
# Quarterly_Tax        0
# Weight               0
# Mfr_Guarantee        0
# BOVAG_Guarantee      0
# Guarantee_Period     0
# ABS                  0
# Airbag_1             0
# Airbag_2             0
# Airco                0
# Automatic_airco      0
# Boardcomputer        0
# CD_Player            0
# Central_Lock         0
# Powered_Windows      0
# Power_Steering       0
# Radio                0
# Mistlamps            0
# Sport_Model          0
# Backseat_Divider     0
# Metallic_Rim         0
# Radio_cassette       0
# Parking_Assistant    0
# Tow_Bar              0
# dtype: int64

# %%
cars.head()
# Out:
#    Id                                              Model  Price  Age_08_04  \
# 0   1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
# 3  11  TOYOTA Corolla 1.8 VVTL-i T-Sport 3-Drs 2/3-Doors  20950         25
# 4  13  TOYOTA Corolla 1.8 16V VVTLI 3DR T SPORT 2/3-D...  19600         25
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color   ...     \
# 0         10      2002  46986    Diesel   90          1   ...
# 1         10      2002  72937    Diesel   90          1   ...
# 2          3      2002  38500    Diesel   90          0   ...
# 3          8      2002  31461    Petrol  192          0   ...
# 4          8      2002  32189    Petrol  192          0   ...
#
#   Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# 0               1               1      0          0            0
# ...

# %%
cars.dtypes
# Out:
# Id                    int64
# Model                object
# Price                 int64
# Age_08_04             int64
# Mfg_Month             int64
# Mfg_Year              int64
# KM                    int64
# Fuel_Type            object
# HP                    int64
# Met_Color             int64
# Color                object
# Automatic             int64
# CC                    int64
# Doors                 int64
# Cylinders             int64
# Gears                 int64
# Quarterly_Tax         int64
# Weight                int64
# Mfr_Guarantee         int64
# BOVAG_Guarantee       int64
# Guarantee_Period      int64
# ABS                   int64
# Airbag_1              int64
# Airbag_2              int64
# Airco                 int64
# Automatic_airco       int64
# Boardcomputer         int64
# CD_Player             int64
# Central_Lock          int64
# Powered_Windows       int64
# Power_Steering        int64
# Radio                 int64
# Mistlamps             int64
# ...

# %%
#X is the dependent variable
X = cars.iloc[:,3:] 

#y includes all the independent variables 
y = cars.iloc[:,2]

#Convert the column into categorical columns
states=pd.get_dummies(X['Fuel_Type'],drop_first=True)

# Drop the state coulmn
X=X.drop('Fuel_Type',axis=1)

# concat the dummy variables
X=pd.concat([X,states],axis=1)



#Convert the column into categorical columns
states=pd.get_dummies(X['Color'],drop_first=True)

#Drop the state coulmn
X=X.drop('Color',axis=1)

#Concat the dummy variables
X=pd.concat([X,states],axis=1)

X
# Out:
#       Age_08_04  Mfg_Month  Mfg_Year      KM   HP  Met_Color  Automatic    CC  \
# 0            23         10      2002   46986   90          1          0  2000
# 1            23         10      2002   72937   90          1          0  2000
# 2            30          3      2002   38500   90          0          0  2000
# 3            25          8      2002   31461  192          0          0  1800
# 4            25          8      2002   32189  192          0          0  1800
# 5            31          2      2002   23000  192          1          0  1800
# 6            28          5      2002   18739  192          0          0  1800
# 7            30          3      2002   34000  192          1          0  1800
# 8            24          9      2002   21716  110          1          0  1600
# 9            30          3      2002   64359  110          1          0  1600
# 10           30          3      2002   67660  110          1          0  1600
# ...

# %%
X.dtypes
# Out:
# Age_08_04            int64
# Mfg_Month            int64
# Mfg_Year             int64
# KM                   int64
# HP                   int64
# Met_Color            int64
# Automatic            int64
# CC                   int64
# Doors                int64
# Cylinders            int64
# Gears                int64
# Quarterly_Tax        int64
# Weight               int64
# Mfr_Guarantee        int64
# BOVAG_Guarantee      int64
# Guarantee_Period     int64
# ABS                  int64
# Airbag_1             int64
# Airbag_2             int64
# Airco                int64
# Automatic_airco      int64
# Boardcomputer        int64
# CD_Player            int64
# Central_Lock         int64
# Powered_Windows      int64
# Power_Steering       int64
# Radio                int64
# Mistlamps            int64
# Sport_Model          int64
# Backseat_Divider     int64
# Metallic_Rim         int64
# Radio_cassette       int64
# Parking_Assistant    int64
# Tow_Bar              int64
# ...

# %%
import matplotlib.pyplot as plt

y.hist(bins=30, figsize=(10,10))

# Add title and axis names
plt.title('Price Distribution',fontsize=18)
plt.xlabel('Price',fontsize=14)
plt.ylabel('No. of Records',fontsize=14)

#plt.show()
plt.savefig('4.jpg')

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score

score=r2_score(y_test,y_pred)
round(score,5)
# Out:
# 0.59295

# %%
import pandas as pd  

cars = pd.read_csv('Online Dataset/Online_Dataset.csv')

X = cars.iloc[:,3:]
y = cars.iloc[:,2]

#Convert the column into categorical columns
states=pd.get_dummies(X['Fuel_Type'],drop_first=True)

# Drop the state coulmn
X=X.drop('Fuel_Type',axis=1)

# concat the dummy variables
X=pd.concat([X,states],axis=1)


#Convert the column into categorical columns
states=pd.get_dummies(X['Color'],drop_first=True)

# Drop the state coulmn
X=X.drop('Color',axis=1)

# concat the dummy variables
X=pd.concat([X,states],axis=1)

X=X.drop(['Cylinders',
          'Age_08_04',
          'Parking_Assistant',
          'Power_Steering',
          'Airbag_1',
          'Airbag_2',
          'Mfg_Month',
          'Met_Color',
          'BOVAG_Guarantee',
          'Mfr_Guarantee',
          'Backseat_Divider',
          'Automatic',
          'HP',
          'Boardcomputer',
          'ABS',
          'Powered_Windows',
          'Mistlamps',
          'Tow_Bar',
          'Sport_Model'
         ], axis=1)

from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm

y_pred = regressor.predict(X_test)

from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)

round(score,5)

#Results
#0.8291557147762473
# Out:
# 0.82916

# %%
#To retrieve the intercept:
print(regressor.intercept_)

#For retrieving the slope:
print(regressor.coef_)
# Out:
# -2674887.217558752
# [ 1.33554218e+03 -1.77283683e-02  4.15280062e-01  7.41958756e+01
#   5.52325550e+02  1.53341677e+01  7.69279358e+00  7.10228877e+01
#   1.33810299e+02  2.82515890e+03  2.39465449e+02  3.59125655e+02
#   4.58894315e+02  2.51240910e+02 -7.16005941e+02  2.17462034e+02
#   1.93600682e+03  5.44794990e+02  3.95688125e+02  1.98611238e+02
#   5.38295276e+02  2.78671899e+02  5.33574374e+02 -5.99029912e+01
#  -1.93372985e+02  0.00000000e+00]

# %%
AP = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
AP.head(15)
# Out:
#      Actual     Predicted
# 479    8250   8915.222458
# 434    8950   9013.582875
# 247   11895  12623.093152
# 784    6450   6705.996832
# 27    13950  13911.540406
# 1     13750  15268.741760
# 261   11450  13356.301156
# 737   10900  10125.136290
# 142   11495  12238.548308
# 877    7950   7490.861195
# 306   10750  10697.171621
# 962    8400   8192.795344
# 271    8900   9964.592522
# 907    5950   6255.475581
# 956    7950   7766.923066

# %%
df1 = cars.head(25)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='1', color='green')
plt.grid(which='minor', linestyle=':', linewidth='1', color='black')

# Add title and axis names
plt.title('Bar graph showing the comparison of Actual and Predicted values',fontsize=18)
plt.xlabel('Records',fontsize=14)
plt.ylabel('Price',fontsize=14)

plt.savefig('6.jpg')

# %%
from sklearn import metrics
import numpy as np  

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1001.4081581206786
# Mean Squared Error: 2268162.54345936
# Root Mean Squared Error: 1506.0420125147107

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

X.hist(bins=50, figsize=(20,15))

plt.savefig("7.jpg")

# %%
X_test = pd.DataFrame({'Mfg_Year':[2002],
           'KM':[64359],
           'CC':[1600],
           'Doors':[3],
           'Gears':[5],
           'Quarterly_Tax':[85],
           'Weight':[1105],
           'Guarantee_Period':[3],
           'Airco':[1],
           'Automatic_airco':[0],
           'CD_Player':[1],
           'Central_Lock':[1],
           'Radio':[0],
           'Metallic_Rim':[0],
           'Radio_cassette':[0],
           'Diesel':[0],
           'Petrol':[1],
           'Black':[0],
           'Blue':[0],
           'Green':[0],
           'Grey':[1],
           'Red':[0],
           'Silver':[0],
           'Violet':[0],
           'White':[0],
           'Yellow':[0]})

y_pred = regressor.predict(X_test)
y_pred

#Actual = 16950
#Predicted = 14599.63079
# Out:
# array([14599.63078921])

# %%
import pandas as pd  

cars = pd.read_csv('Online Dataset/Online_Dataset.csv')

X = cars.iloc[:,3:]
y = cars.iloc[:,2]

#Convert the column into categorical columns
states=pd.get_dummies(X['Fuel_Type'],drop_first=True)

# Drop the state coulmn
X=X.drop('Fuel_Type',axis=1)

# concat the dummy variables
X=pd.concat([X,states],axis=1)


#Convert the column into categorical columns
states=pd.get_dummies(X['Color'],drop_first=True)

# Drop the state coulmn
X=X.drop('Color',axis=1)

# concat the dummy variables
X=pd.concat([X,states],axis=1)

X=X.drop(['Cylinders',
          'Age_08_04',
          'Parking_Assistant',
          'Power_Steering',
          'Airbag_1',
          'Airbag_2',
          'Mfg_Month',
          'Met_Color',
          'BOVAG_Guarantee',
          'Mfr_Guarantee',
          'Backseat_Divider',
          'Automatic',
          'HP',
          'Boardcomputer',
          'ABS',
          'Powered_Windows',
          'Mistlamps',
          'Tow_Bar',
          'Sport_Model'
         ], axis=1)

from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=20, random_state=0)  
regressor.fit(X_train, y_train)  

y_pred = regressor.predict(X_test)

from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)

round(score,5)

#Results
#0.86562
# Out:
# 0.86562

# %%
#With Z score----------

import pandas as pd  

cars = pd.read_csv('Online Dataset/Online_Dataset.csv')

X = cars.iloc[:,3:]
y = cars.iloc[:,2]

#Convert the column into categorical columns
states=pd.get_dummies(X['Fuel_Type'],drop_first=True)

# Drop the state coulmn
X=X.drop('Fuel_Type',axis=1)

# concat the dummy variables
X=pd.concat([X,states],axis=1)


#Convert the column into categorical columns
states=pd.get_dummies(X['Color'],drop_first=True)

# Drop the state coulmn
X=X.drop('Color',axis=1)

# concat the dummy variables
X=pd.concat([X,states],axis=1)

X=X.drop(['Cylinders',
          'Age_08_04',
          'Parking_Assistant',
          'Power_Steering',
          'Airbag_1',
          'Airbag_2',
          'Mfg_Month',
          'Met_Color',
          'BOVAG_Guarantee',
          'Mfr_Guarantee',
          'Backseat_Divider',
          'Automatic',
          'HP',
          'Boardcomputer',
          'ABS',
          'Powered_Windows',
          'Mistlamps',
          'Tow_Bar',
          'Sport_Model'
         ], axis=1)

#Get zcores for non bitmap indexed fields
Z_Fields = X.iloc[:,0:8] 

cols = list(Z_Fields.columns)
for col in cols:
    
        col_zscore = col + '_zscore'
        X[col_zscore] = (Z_Fields[col] - Z_Fields[col].mean())/Z_Fields[col].std(ddof=0)

X=X.iloc[:,8:] 

from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=20, random_state=0)  
regressor.fit(X_train, y_train)  

y_pred = regressor.predict(X_test)

from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)

round(score,5)

#Results
#0.86672
# Out:
# 0.86672

# %%
from sklearn import metrics
import numpy as np  

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 922.3053921568627
# Mean Squared Error: 1769476.1612009804
# Root Mean Squared Error: 1330.2165843203807

# %%
X_test = pd.DataFrame({'Mfg_Year':[2002],
           'KM':[64359],
           'CC':[1600],
           'Doors':[3],
           'Gears':[5],
           'Quarterly_Tax':[85],
           'Weight':[1105],
           'Guarantee_Period':[3],
           'Airco':[1],
           'Automatic_airco':[0],
           'CD_Player':[1],
           'Central_Lock':[1],
           'Radio':[0],
           'Metallic_Rim':[0],
           'Radio_cassette':[0],
           'Diesel':[0],
           'Petrol':[1],
           'Black':[0],
           'Blue':[0],
           'Green':[0],
           'Grey':[1],
           'Red':[0],
           'Silver':[0],
           'Violet':[0],
           'White':[0],
           'Yellow':[0]})

y_pred = regressor.predict(X_test)
y_pred
#16530
# Out:
# array([16530.])

# %%
import pandas as pd  

cars = pd.read_csv('Online Dataset/Online_Dataset.csv')

X = cars.iloc[:,3:]
y = cars.iloc[:,2]

#Convert the column into categorical columns
states=pd.get_dummies(X['Fuel_Type'],drop_first=True)

# Drop the state coulmn
X=X.drop('Fuel_Type',axis=1)

# concat the dummy variables
X=pd.concat([X,states],axis=1)


#Convert the column into categorical columns
states=pd.get_dummies(X['Color'],drop_first=True)

# Drop the state coulmn
X=X.drop('Color',axis=1)

# concat the dummy variables
X=pd.concat([X,states],axis=1)

X=X.drop(['Cylinders',
          'Age_08_04',
          'Parking_Assistant',
          'Power_Steering',
          'Airbag_1',
          'Airbag_2',
          'Mfg_Month',
          'Met_Color',
          'BOVAG_Guarantee',
          'Mfr_Guarantee',
          'Backseat_Divider',
          'Automatic',
          'HP',
          'Boardcomputer',
          'ABS',
          'Powered_Windows',
          'Mistlamps',
          'Tow_Bar',
          'Sport_Model'
         ], axis=1)

from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

from sklearn.neighbors import KNeighborsRegressor
regressor = KNeighborsRegressor(n_neighbors=85)
regressor.fit(X_train, y_train)  

y_pred = regressor.predict(X_test)

from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)

round(score,5)

#Results
#0.34693
# Out:
# 0.34693

# %%
from sklearn import metrics
import numpy as np  

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 2064.0557093425605
# Mean Squared Error: 8670254.505990908
# Root Mean Squared Error: 2944.529589932984

# %%
import numpy as np  
X_test = pd.DataFrame({'Mfg_Year':[2002],
           'KM':[64359],
           'CC':[1600],
           'Doors':[3],
           'Gears':[5],
           'Quarterly_Tax':[85],
           'Weight':[1105],
           'Guarantee_Period':[3],
           'Airco':[1],
           'Automatic_airco':[0],
           'CD_Player':[1],
           'Central_Lock':[1],
           'Radio':[0],
           'Metallic_Rim':[0],
           'Radio_cassette':[0],
           'Diesel':[0],
           'Petrol':[1],
           'Black':[0],
           'Blue':[0],
           'Green':[0],
           'Grey':[1],
           'Red':[0],
           'Silver':[0],
           'Violet':[0],
           'White':[0],
           'Yellow':[0]})

y_pred = regressor.predict(X_test)
y_pred

#Actual = 16950
#Predicted = 10115.87058
# Out:
# array([10115.87058824])

# %%
import pandas as pd  

cars = pd.read_csv('Online Dataset/Online_Dataset.csv')

X = cars.iloc[:,3:]
y = cars.iloc[:,2]

#Convert the column into categorical columns
states=pd.get_dummies(X['Fuel_Type'],drop_first=True)

# Drop the state coulmn
X=X.drop('Fuel_Type',axis=1)

# concat the dummy variables
X=pd.concat([X,states],axis=1)


#Convert the column into categorical columns
states=pd.get_dummies(X['Color'],drop_first=True)

# Drop the state coulmn
X=X.drop('Color',axis=1)

# concat the dummy variables
X=pd.concat([X,states],axis=1)

X=X.drop(['Cylinders',
          'Age_08_04',
          'Parking_Assistant',
          'Power_Steering',
          'Airbag_1',
          'Airbag_2',
          'Mfg_Month',
          'Met_Color',
          'BOVAG_Guarantee',
          'Mfr_Guarantee',
          'Backseat_Divider',
          'Automatic',
          'HP',
          'Boardcomputer',
          'ABS',
          'Powered_Windows',
          'Mistlamps',
          'Tow_Bar',
          'Sport_Model'
         ], axis=1)

from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

from sklearn.tree import DecisionTreeClassifier

regressor = DecisionTreeClassifier()
regressor.fit(X_train, y_train)  

y_pred = regressor.predict(X_test)

from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)

round(score,5)

#Results
#0.8034
# Out:
# 0.78054

# %%
from sklearn import metrics
import numpy as np  

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1268.3529411764705
# Mean Squared Error: 3111601.3529411764
# Root Mean Squared Error: 1763.9731723983718

# %%
import numpy as np  
X_test = pd.DataFrame({'Mfg_Year':[2002],
           'KM':[64359],
           'CC':[1600],
           'Doors':[3],
           'Gears':[5],
           'Quarterly_Tax':[85],
           'Weight':[1105],
           'Guarantee_Period':[3],
           'Airco':[1],
           'Automatic_airco':[0],
           'CD_Player':[1],
           'Central_Lock':[1],
           'Radio':[0],
           'Metallic_Rim':[0],
           'Radio_cassette':[0],
           'Diesel':[0],
           'Petrol':[1],
           'Black':[0],
           'Blue':[0],
           'Green':[0],
           'Grey':[1],
           'Red':[0],
           'Silver':[0],
           'Violet':[0],
           'White':[0],
           'Yellow':[0]})

y_pred = regressor.predict(X_test)
y_pred

#Actual = 16950
#Predicted = 16950
# Out:
# array([16950], dtype=int64)

# %%
import pandas as pd  

cars = pd.read_csv('Online Dataset/Online_Dataset.csv')

X = cars.iloc[:,3:]
y = cars.iloc[:,2]

#Convert the column into categorical columns
states=pd.get_dummies(X['Fuel_Type'],drop_first=True)

# Drop the state coulmn
X=X.drop('Fuel_Type',axis=1)

# concat the dummy variables
X=pd.concat([X,states],axis=1)


#Convert the column into categorical columns
states=pd.get_dummies(X['Color'],drop_first=True)

# Drop the state coulmn
X=X.drop('Color',axis=1)

# concat the dummy variables
X=pd.concat([X,states],axis=1)

X=X.drop(['Cylinders',
          'Age_08_04',
          'Parking_Assistant',
          'Power_Steering',
          'Airbag_1',
          'Airbag_2',
          'Mfg_Month',
          'Met_Color',
          'BOVAG_Guarantee',
          'Mfr_Guarantee',
          'Backseat_Divider',
          'Automatic',
          'HP',
          'Boardcomputer',
          'ABS',
          'Powered_Windows',
          'Mistlamps',
          'Tow_Bar',
          'Sport_Model'
         ], axis=1)

from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

from sklearn.ensemble import GradientBoostingRegressor

regressor = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=10, random_state=0)
regressor.fit(X_train, y_train)  

y_pred = regressor.predict(X_test)

from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)

round(score,5)

#Results
#0.87992
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# 0.87992

# %%
from sklearn import metrics
import numpy as np  

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 875.5165084731068
# Mean Squared Error: 1594194.9200320828
# Root Mean Squared Error: 1262.6143195893521

# %%
import numpy as np  
X_test = pd.DataFrame({'Mfg_Year':[2002],
           'KM':[64359],
           'CC':[1600],
           'Doors':[3],
           'Gears':[5],
           'Quarterly_Tax':[85],
           'Weight':[1105],
           'Guarantee_Period':[3],
           'Airco':[1],
           'Automatic_airco':[0],
           'CD_Player':[1],
           'Central_Lock':[1],
           'Radio':[0],
           'Metallic_Rim':[0],
           'Radio_cassette':[0],
           'Diesel':[0],
           'Petrol':[1],
           'Black':[0],
           'Blue':[0],
           'Green':[0],
           'Grey':[1],
           'Red':[0],
           'Silver':[0],
           'Violet':[0],
           'White':[0],
           'Yellow':[0]})

y_pred = regressor.predict(X_test)
y_pred

#Actual = 16950
#Predicted = 16947.7037
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b3217c6c528c> in <module>()
#       1 import numpy as np
# ----> 2 X_test = pd.DataFrame({'Mfg_Year':[2002],
#       3            'KM':[64359],
#       4            'CC':[1600],
#       5            'Doors':[3],
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd  

#train.csv is the chosen dataset
cars = pd.read_csv('Sri Lankan Dataset/Sri_Lankan_Dataset.csv')
cars.isnull().sum()
# Out:
# Model year         0
# Condition          0
# Transmission       0
# Body type          0
# Fuel type          0
# Engine capacity    0
# Mileage            0
# Price              0
# dtype: int64

# %%
cars.head()
# Out:
#    Model year Condition Transmission Body type Fuel type  Engine capacity  \
# 0        2004      Used    Automatic    Saloon    Petrol             1500
# 1        1997      Used    Automatic    Saloon    Diesel             1998
# 2        2007      Used    Automatic    Saloon    Petrol             1600
# 3        2003      Used       Manual    Saloon    Petrol             1500
# 4        1989      Used       Manual    Saloon    Petrol             1300
#
#    Mileage    Price
# 0    98000  3475000
# 1   167000  1890000
# 2   136000  3150000
# 3    89300  2775000
# 4   235000   650000

# %%
# Drop the Condition coulmn
cars=cars.drop('Condition',axis=1)
cars.head()
# Out:
#    Model year Transmission Body type Fuel type  Engine capacity  Mileage  \
# 0        2004    Automatic    Saloon    Petrol             1500    98000
# 1        1997    Automatic    Saloon    Diesel             1998   167000
# 2        2007    Automatic    Saloon    Petrol             1600   136000
# 3        2003       Manual    Saloon    Petrol             1500    89300
# 4        1989       Manual    Saloon    Petrol             1300   235000
#
#      Price
# 0  3475000
# 1  1890000
# 2  3150000
# 3  2775000
# 4   650000

# %%
cars = cars[['Price', 'Model year','Engine capacity','Mileage', 'Transmission', 'Body type', 'Fuel type']]
cars.head()
# Out:
#      Price  Model year  Engine capacity  Mileage Transmission Body type  \
# 0  3475000        2004             1500    98000    Automatic    Saloon
# 1  1890000        1997             1998   167000    Automatic    Saloon
# 2  3150000        2007             1600   136000    Automatic    Saloon
# 3  2775000        2003             1500    89300       Manual    Saloon
# 4   650000        1989             1300   235000       Manual    Saloon
#
#   Fuel type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Petrol
# 4    Petrol

# %%
X = cars.iloc[:,1:] 
y = cars.iloc[:,0]

# %%
X.dtypes
# Out:
# Model year          int64
# Engine capacity     int64
# Mileage             int64
# Transmission       object
# Body type          object
# Fuel type          object
# dtype: object

# %%
#Convert the column into categorical columns
states=pd.get_dummies(X['Transmission'],drop_first=True)

# Drop the Transmission coulmn
X=X.drop('Transmission',axis=1)

# concat the dummy variables
X=pd.concat([X,states],axis=1)

#Convert the column into categorical columns
states=pd.get_dummies(X['Body type'],drop_first=True)

# Drop the Body type coulmn
X=X.drop('Body type',axis=1)

# concat the dummy variables
X=pd.concat([X,states],axis=1)

#Convert the column into categorical columns
states=pd.get_dummies(X['Fuel type'],drop_first=True)

# Drop the Fuel type coulmn
X=X.drop('Fuel type',axis=1)

# concat the dummy variables
X=pd.concat([X,states],axis=1)

X.head()
# Out:
#    Model year  Engine capacity  Mileage  Manual  Hatchback  Saloon  \
# 0        2004             1500    98000       0          0       1
# 1        1997             1998   167000       0          0       1
# 2        2007             1600   136000       0          0       1
# 3        2003             1500    89300       1          0       1
# 4        1989             1300   235000       1          0       1
#
#    Station wagon  Diesel, Other fuel type  Petrol  Petrol, Other fuel type
# 0              0                        0       1                        0
# 1              0                        0       0                        0
# 2              0                        0       1                        0
# 3              0                        0       1                        0
# 4              0                        0       1                        0

# %%
X.dtypes
# Out:
# Model year                 int64
# Engine capacity            int64
# Mileage                    int64
# Manual                     uint8
# Hatchback                  uint8
# Saloon                     uint8
# Station wagon              uint8
# Diesel, Other fuel type    uint8
# Petrol                     uint8
# Petrol, Other fuel type    uint8
# dtype: object

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

from sklearn.linear_model import LinearRegression
regressor = LinearRegression() 
regressor.fit(X_train, y_train)  

y_pred = regressor.predict(X_test)

from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
round(score,5)

#Results
#0.83042
# Out:
# 0.83042

# %%
from sklearn import metrics
import numpy as np  

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 289115.5142364708
# Mean Squared Error: 138840881226.7054
# Root Mean Squared Error: 372613.5816455238

# %%
X_test.head()
# Out:
#      Model year  Engine capacity  Mileage  Manual  Hatchback  Saloon  \
# 113        1995             1500   300000       1          0       1
# 184        2002             1500   129000       0          0       1
# 56         1997             2000   245000       0          0       1
# 89         2004             1500   171000       1          0       1
# 12         2005             1500   135000       0          0       1
#
#      Station wagon  Diesel, Other fuel type  Petrol  Petrol, Other fuel type
# 113              0                        0       1                        0
# 184              0                        0       1                        0
# 56               0                        0       0                        0
# 89               0                        0       1                        0
# 12               0                        0       1                        0

# %%
import numpy as np  

X_test = pd.DataFrame({'Model year':[2002],
           'Engine capacity':[1500],
            'Mileage':[129000],           
           'Manual':[0],
           'Hatchback':[0],
           'Saloon':[1],
           'Station wagon':[0],
           'Diesel, Other fuel type':[0],
           'Petrol':[1],
           'Petrol, Other fuel type':[0],})

y_pred = regressor.predict(X_test)
y_pred

#Actual = 3075000
#Predicted = 2810549.885
# Out:
# array([2810549.88506934])

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators=20, random_state=0)  
regressor.fit(X_train, y_train)  

y_pred = regressor.predict(X_test)

from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
round(score,5)

#Results
#0.84358
# Out:
# 0.84358

# %%
from sklearn import metrics
import numpy as np  

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 267161.32478632475
# Mean Squared Error: 128068651931.98004
# Root Mean Squared Error: 357866.8075303716

# %%
import numpy as np  

X_test = pd.DataFrame({'Model year':[2002],
           'Engine capacity':[1500],
            'Mileage':[129000],           
           'Manual':[0],
           'Hatchback':[0],
           'Saloon':[1],
           'Station wagon':[0],
           'Diesel, Other fuel type':[0],
           'Petrol':[1],
           'Petrol, Other fuel type':[0],})

y_pred = regressor.predict(X_test)
y_pred

#Actual = 3075000
#Predicted = 2855000
# Out:
# array([2810549.88506934])

# %%
from sklearn.tree import DecisionTreeClassifier

regressor = DecisionTreeClassifier()
regressor.fit(X_train, y_train)  

y_pred = regressor.predict(X_test)

from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)

round(score,5)

#Results
#0.89032
# Out:
# 0.84092

# %%
from sklearn import metrics
import numpy as np  

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 230512.8205128205
# Mean Squared Error: 89802564102.5641
# Root Mean Squared Error: 299670.7595054347

# %%
import numpy as np  

X_test = pd.DataFrame({'Model year':[2002],
           'Engine capacity':[1500],
            'Mileage':[129000],           
           'Manual':[0],
           'Hatchback':[0],
           'Saloon':[1],
           'Station wagon':[0],
           'Diesel, Other fuel type':[0],
           'Petrol':[1],
           'Petrol, Other fuel type':[0],})

y_pred = regressor.predict(X_test)
y_pred

#Actual = 3075000
#Predicted = 3295000
# Out:
# array([3400000], dtype=int64)

# %%
from sklearn.ensemble import GradientBoostingRegressor

regressor = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=10, random_state=0)
regressor.fit(X_train, y_train)  

y_pred = regressor.predict(X_test)

from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)

round(score,5)

#Results
#0.69906
# Out:
# 0.69906

# %%
from sklearn import metrics
import numpy as np  

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 334542.9754688997
# Mean Squared Error: 246394403939.0665
# Root Mean Squared Error: 496381.3090146188

# %%
import numpy as np  

X_test = pd.DataFrame({'Model year':[2002],
           'Engine capacity':[1500],
            'Mileage':[129000],           
           'Manual':[0],
           'Hatchback':[0],
           'Saloon':[1],
           'Station wagon':[0],
           'Diesel, Other fuel type':[0],
           'Petrol':[1],
           'Petrol, Other fuel type':[0],})

y_pred = regressor.predict(X_test)
y_pred

#Actual = 3075000
#Predicted = 2844771.602
# Out:
# array([2844771.60272111])

# %%
from sklearn.neighbors import KNeighborsRegressor
regressor = KNeighborsRegressor(n_neighbors=85)
regressor.fit(X_train, y_train)  

y_pred = regressor.predict(X_test)

from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)

round(score,5)

#Results
#0.34693
# Out:
# 0.09153
